# %% [markdown]
# # Exploratory analysis of the data
#
# We have to main datasets: Experience and contracts.
#
# Public workers must declare their previous work-experience, income, among other things. These attributes are put together in the experience dataset.
#
# Contracts on the other hand deals with public procurement: the process by which governments purchase goods, services and contruction works from the private sector.

# %%
import pandas as pd
import numpy as np

# %%
from glob import glob

# %% [markdown]
# ## Public procurement

# %%
contracts = pd.read_csv('/home/rdora/declaranet/data/pre-process/contracts.csv')

# %%
contracts = contracts.drop_duplicates()

# %%
expediente = pd.read_csv('/home/rdora/declaranet/data/pre-process/expedientes.csv')

# %%
cuco = pd.read_excel('/home/rdora/declaranet/data/tables/CUCOP_200528064626.xlsx')

# %%
gemo = pd.read_excel('/home/rdora/declaranet/data/tables/GEMOrganismos_180308060030.xlsx')

# %%
inst = pd.read_excel('/home/rdora/declaranet/data/tables/Instituciones_200528070439.xlsx')

# %%
rupc2 = pd.read_excel('/home/rdora/declaranet/data/tables/RUPC_200504061520.xlsx')

# %%
col_drop = ['fecha_apertura_proposiciones',
           'caracter',
           'forma_procedimiento',
           'titulo_contrato',
           'codigo_contrato',
           'estatus_contrato',
           'estratificacion_mpc']

# %%
contratos = contratos.drop(col_drop, axis=1)

# %%
contratos = pd.read_csv('/home/rdora/declaranet/data/tables/contratos.csv')
# Out:
# /home/rdora/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sinrupc = pd.read_csv('/home/rdora/declaranet/data/pre-process/sin_rupec.csv')

# %%
rupc = pd.read_csv('/home/rdora/declaranet/data/tables/RUPC.csv', encoding='latin')

# %%
sinrupc['person'] = sinrupc.titularidad_juridica.where(
    sinrupc.titularidad_juridica=='4.- Persona Física con Actividad Empresarial (Empresario Individual)', other=0)

# %%
sinrupc['person'] = sinrupc['person'].replace({'4.- Persona Física con Actividad Empresarial (Empresario Individual)': 1})

# %%
rupc['person'] = 0

# %%
rupc.loc[rupc['RFC'].isna(), 'person'] = 1

# %%
rename = {'Folio RUPC': 'folio_rupc', 'Entidad Federativa': 's_entidad_federativa'}
rupc = rupc[['Folio RUPC', 'Entidad Federativa', 'person']].rename(columns=rename)

# %%
sinrupc = sinrupc[['proveedor_contratista', 'entidad_federativa', 'person']].rename(columns={'entidad_federativa': 's_entidad_federativa'})

# %%
uc = pd.read_excel('/home/rdora/declaranet/data/tables/UC_200529064722.xlsx')

# %%
ren = {'Ramo': 'n_ramo',
       'Nombre de la UC': 'nombre_de_la_uc',
       'Entidad Federativa': 'n_entidad_federativa'}
uc = uc.rename(columns=ren)[['n_ramo', 'nombre_de_la_uc', 'n_entidad_federativa']]
cnts = pd.merge(cnts, uc, how='left', on='nombre_de_la_uc')

# %%
cnts.loc[(cnts.n_ramo.notna()) & (cnts.ramo.isna()), 'ramo'] = cnts.loc[(cnts.n_ramo.notna()) & (cnts.ramo.isna()), 'n_ramo']

# %%
cnts.loc[(cnts.n_entidad_federativa.notna()) & (cnts.b_entidad_federativa.isna()), 'b_entidad_federativa'] = cnts.loc[(cnts.n_entidad_federativa.notna()) & (cnts.b_entidad_federativa.isna()), 'n_entidad_federativa']

# %%
cnts.loc[(cnts.entidad_federativa.notna()) & (cnts.b_entidad_federativa.isna()), 'b_entidad_federativa'] = cnts.loc[(cnts.entidad_federativa.notna()) & (cnts.b_entidad_federativa.isna()), 'entidad_federativa']

# %%
cnts.ramo.unique()
# Out:
# array([18.0, nan, 51.0, 6.0, 4.0, 50.0, 12.0, 913.0, 38.0, 9.0, 920.0,
#        47.0, 926.0, 931.0, 902.0, 16.0, 10.0, 11.0, 910.0, 21.0, 925.0,
#        13.0, 48.0, 14.0, 917.0, 8.0, 914.0, 37.0, 20.0, 32.0, 928.0, 2.0,
#        932.0, 915.0, 919.0, 7.0, 903.0, 905.0, 923.0, 901.0, 27.0, 909.0,
#        40.0, 815.0, 828.0, 15.0, 930.0, 916.0, 801.0, 921.0, 830.0, 927.0,
#        827.0, 810.0, 805.0, 922.0, 912.0, 904.0, 821.0, 819.0, 823.0,
#        924.0, 907.0, 811.0, 818.0, 911.0, 831.0, 825.0, 826.0, 822.0,
#        908.0, 807.0, 816.0, 906.0, 832.0, 918.0, 803.0, 814.0, 820.0,
#        813.0, 808.0, 802.0, 929.0, 46.0, 812.0, 804.0, 824.0, 806.0,
#        829.0, 809.0, 49.0, 44.0, 36.0, 31.0, 45.0, 41.0, 5.0, 43.0, 817.0],
#       dtype=object)

# %%
cnts['ramo'] = cnts['i_ramo']

# %%
gemo.head()
# Out:
#    ID_DEP_ENT SIGLAS                          ORGANISMO     ID_UR  \
# 0         932    ZAC  _Gobierno del Estado de Zacatecas  932073.0
# 1         932    ZAC  _Gobierno del Estado de Zacatecas  932037.0
# 2         932    ZAC  _Gobierno del Estado de Zacatecas  932039.0
# 3         932    ZAC  _Gobierno del Estado de Zacatecas  932041.0
# 4         932    ZAC  _Gobierno del Estado de Zacatecas  932029.0
#
#                                               NOMBRE          TIPO
# 0  Centro Regional del Patrimonio Mundial en Zaca...  Ente Público
# 1     Colegio de Bachilleres del Estado de Zacatecas  Ente Público
# 2  Colegio de Educación Profesional Técnica del E...  Ente Público
# 3  Colegio de Estudios Científicos y Tecnológicos...  Ente Público
# 4  Comisión Estatal de Agua Potable y Alcantarillado  Ente Público

# %%
state_dict = {}
unames = cnts[(cnts['b_entidad_federativa'].isna())]['nombre_de_la_uc'].unique()
for uname in unames:
    uname2 = uname.lower()
    for i, state in enumerate(ef2):
        if state in uname2:
            state_dict[uname] = ef[i]

# %%
for i, row in cnts[(cnts['b_entidad_federativa'].isna())].iterrows():
    name = row['nombre_de_la_uc']
    if name in state_dict:
        cnts.loc[i, 'b_entidad_federativa'] = state_dict[name]

# %%
str.

# %%
cols_drop = ['dependencia',
             'entidad_federativa',
             'n_ramo',
             'n_entidad_federativa',
             'i_ramo',
             'anuncio',
             'nombre_de_la_uc',
             'claveuc',
             'codigo_expediente',
             'tipo_contratacion',
             'folio_rupc',
             'responsable']

# %%
cnts = cnts.drop(['responsable'], axis=1)

# %%
cnts2 = pd.read_csv('/home/rdora/declaranet/data/pre-process/contratos_3.csv')

# %%
cnts2.columns
# Out:
# Index(['gobierno', 'siglas', 'dependencia', 'claveuc', 'nombre_de_la_uc',
#        'responsable', 'codigo_expediente', 'tipo_contratacion',
#        'tipo_procedimiento', 'fecha_inicio', 'fecha_fin', 'importe_contrato',
#        'moneda', 'folio_rupc', 'proveedor_contratista', 'siglas_pais',
#        'anuncio', 's_entidad_federativa', 'person', 'entidad_federativa',
#        'ramo', 'b_entidad_federativa', 'n_ramo', 'n_entidad_federativa',
#        'i_ramo'],
#       dtype='object')

# %%
expediente.head()
# Out:
#    codigo_expediente entidad_federativa
# 0            2072529   ciudad de mexico
# 1            2072544   ciudad de mexico
# 2            2059957   ciudad de mexico
# 3            2058318   ciudad de mexico
# 4            2066386   ciudad de mexico

# %%
cnts.to_csv('/home/rdora/declaranet/data/pre-process/contratos_4.csv', index=False)

# %%
cnts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249835 entries, 0 to 1249834
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   gobierno               1249835 non-null  object
#  1   siglas                 1249835 non-null  object
#  2   tipo_procedimiento     1249425 non-null  object
#  3   fecha_inicio           1249835 non-null  object
#  4   fecha_fin              1249761 non-null  object
#  5   importe_contrato       1249835 non-null  float64
#  6   moneda                 1249835 non-null  object
#  7   proveedor_contratista  1249835 non-null  object
#  8   siglas_pais            1249835 non-null  object
#  9   s_entidad_federativa   1249835 non-null  object
#  10  person                 1249835 non-null  float64
#  11  ramo                   1249835 non-null  int64
#  12  b_entidad_federativa   1249409 non-null  object
# dtypes: float64(2), int64(1), object(10)
# ...

# %%
cnts.columns
# Out:
# Index(['gobierno', 'siglas', 'dependencia', 'claveuc', 'nombre_de_la_uc',
#        'responsable', 'codigo_expediente', 'tipo_contratacion',
#        'tipo_procedimiento', 'fecha_inicio', 'fecha_fin', 'importe_contrato',
#        'moneda', 'folio_rupc', 'proveedor_contratista', 'siglas_pais',
#        'anuncio', 's_entidad_federativa', 'person', 'entidad_federativa',
#        'ramo', 'b_entidad_federativa', 'n_ramo', 'n_entidad_federativa',
#        'i_ramo'],
#       dtype='object')

# %%
cnts.head()
# Out:
#   gobierno   siglas                                        dependencia  \
# 0      APF      CFE                   Comisión Federal de Electricidad
# 1      APF  LICONSA                              Liconsa, S.A. de C.V.
# 2      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 3      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 4      APF      CFE                   Comisión Federal de Electricidad
#
#      claveuc                                    nombre_de_la_uc  \
# 0  018TOQ045  CFE-Central Termoeléctrica Punta Prieta en La ...
# 1  020VST004  LICONSA-Subdirección de Adquisición y Distribu...
# 2  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 3  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 4  018TOQ011  CFE-DEPTO. DE COMPRAS DE LA DIVISION BAJIO #01...
#
#                      responsable codigo_expediente tipo_contratacion  \
# 0  Jose Ascención Salas Pallares            117806     Adquisiciones
# ...

# %%
ef
# Out:
# array(['MX-SIN', 'MX-JAL', 'MX-MOR', 'MX-CMX', 'MX-MEX', 'MX-VER',
#        'MX-CHP', 'MX-SON', 'MX-TAB', 'MX-NLE', 'MX-TAM', 'MX-DUR',
#        'MX-BCS', 'MX-BCN', 'MX-QUE', 'MX-PUE', 'MX-SLP', 'MX-OAX',
#        'MX-MIC', 'MX-YUC', 'MX-COA', 'MX-GUA', 'MX-HID', 'MX-COL',
#        'MX-CHH', 'MX-ZAC', 'MX-AGU', 'MX-ROO', 'MX-GRO', 'MX-CAM',
#        'MX-NAY', 'MX-TLA'], dtype=object)

# %%
cnts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249835 entries, 0 to 1249834
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   gobierno               1249835 non-null  object
#  1   siglas                 1249835 non-null  object
#  2   dependencia            1249835 non-null  object
#  3   claveuc                1249835 non-null  object
#  4   nombre_de_la_uc        1249835 non-null  object
#  5   responsable            1249835 non-null  object
#  6   codigo_expediente      1249835 non-null  object
#  7   tipo_contratacion      1247187 non-null  object
#  8   tipo_procedimiento     1249425 non-null  object
#  9   fecha_inicio           1249835 non-null  object
#  10  fecha_fin              1249761 non-null  object
#  11  importe_contrato       1249835 non-null  float64
#  12  moneda                 1249835 non-null  object
#  13  folio_rupc             583532 non-null   float64
# ...

# %%
cnts.head()
# Out:
#   gobierno   siglas                                        dependencia  \
# 0      APF      CFE                   Comisión Federal de Electricidad
# 1      APF  LICONSA                              Liconsa, S.A. de C.V.
# 2      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 3      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 4      APF      CFE                   Comisión Federal de Electricidad
#
#      claveuc                                    nombre_de_la_uc  \
# 0  018TOQ045  CFE-Central Termoeléctrica Punta Prieta en La ...
# 1  020VST004  LICONSA-Subdirección de Adquisición y Distribu...
# 2  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 3  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 4  018TOQ011  CFE-DEPTO. DE COMPRAS DE LA DIVISION BAJIO #01...
#
#                      responsable codigo_expediente tipo_contratacion  \
# 0  Jose Ascención Salas Pallares            117806     Adquisiciones
# ...

# %%
cnts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249835 entries, 0 to 1249834
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   gobierno               1249835 non-null  object
#  1   siglas                 1249835 non-null  object
#  2   dependencia            1249835 non-null  object
#  3   claveuc                1249835 non-null  object
#  4   nombre_de_la_uc        1249835 non-null  object
#  5   responsable            1249835 non-null  object
#  6   codigo_expediente      1249835 non-null  object
#  7   tipo_contratacion      1247187 non-null  object
#  8   tipo_procedimiento     1249425 non-null  object
#  9   fecha_inicio           1249835 non-null  object
#  10  fecha_fin              1249761 non-null  object
#  11  importe_contrato       1249835 non-null  float64
#  12  moneda                 1249835 non-null  object
#  13  folio_rupc             583532 non-null   float64
# ...

# %%
cnts.to_csv('/home/rdora/declaranet/rdora/declaranet/data/pre-process/contratos_3.csv', index=False)

# %%
for i, row in cnts[(cnts['b_entidad_federativa'].isna())].iterrows():
    name = row['nombre_de_la_uc']
    if name in state_dict_2:
        cnts.loc[i, 'b_entidad_federativa'] = state_dict_2[name]

# %%
state_dict_2 = {'LICONSA-Adquisiciones y Servicios Generales #020VST002': 'MX-MEX',
                'LICONSA-Subdirección de Adquisición de Leche en Naucalpan, Estado de México #020VST012': 'MX-MEX',
                'SAT-Administración General de Recursos y Servicios, Administración Central de Recursos Materiales #006E00001': 'MX-CMX',
                'CISEN-Dirección de Recursos Materiales y Servicios Generales #004I00001': 'MX-CMX',
                'PF-Dir. Gral. de Rec. Mat. a través de la Dir. de Adquisiciones #004L00001': 'MX-CMX',
                'LICONSA-Subdirección de Adquisiciones de Consumo Interno #020VST001': 'MX-MEX',
                'SPF-DIRECCIÓN DE ADQUISICIONES #004O00001': 'MX-CMX',
                'SCT-Coordinación Administrativa de la Oficialía Mayor #009000989': 'MX-CMX',
                'SCT-Coordinación Administrativa de la Oficialía Mayor #009000989': 'MX-CMX',
                'SE-Dirección de Contrataciones #010000999': 'MX-CMX',
                'IFAI-Dirección General de Administración #006HHE001': 'MX-CMX',
                'DICONSA-Dirección de Comercialización #020VSS998': 'MX-CMX',
                'SCT-Subdirección de Obras #009000947': 'MX-MIC',
                'SADER-DIRECCIÓN GENERAL DE RECURSOS MATERIALES, INMUEBLES Y SERVICIOS #008000999': 'MX-CMX',
                'SAT-Subadministración de Recursos y Servicios de Pachuca #006E00027': 'MX-HID',
                'COFECE-DGA DGRMAS #041A00001': 'MX-CMX',
                'LICONSA-Gerencia Metropolitana Sur #020VST003': 'MX-MEX',
                'SHCP-Dirección de Contrataciones #006000998': 'MX-CMX',
                'PGR-Dirección de Adquisiciones #017000999': 'MX-CMX',
                'SAE-Dirección Ejecutiva de Administración de Recursos Financieros y Materiales #006HKA001': 'MX-CMX',
                'DICONSA-GERENCIA DE SUCURSAL #020VSS015': 'MX-SON',
                'SAT-Subadministración de Recursos y Servicios de Tampico #006E00045': 'MX-TAM',
                'INEE-Dirección General de Administración y Finanzas #006A2O001': 'MX-CMX',
                'SECTUR-Dirección General Adjunta de Recursos Materiales y Servicios Generales #021000999': 'MX-CMX',

                'BIENESTAR-Dirección General Adjunta de Adquisiciones, Administración, Inmobiliaria y Activo Fijo #020000999' : 'MX-CMX',
                'LICONSA-Subgerencia de Administración y Finanzas #020VST018': 'MX-MEX',
                'SCT-Departamento de Recursos Materiales #009000974': 'MX-DUR',
                'SRE-Dirección General Adjunta de Adquisiciones y Contrataciones #005000999': 'MX-CMX',
                'SEGOB-Subdirección de Adquisiciones #004000998': 'MX-CMX',
                'SAT-Subaministración de Recursos y Servicios de Culiacán #006E00007': 'MX-SIN',
                'FIT-GERENCIA DE ADQUISICIONES, RECURSOS MATERIALES Y OBRA PUBLICA #009J3L001': 'MX-CMX',
                'LICONSA-Subgerencia de Administración y Finanzas en Querétaro #020VST009': 'MX-QUE',
                'DICONSA-Diconsa Sucursal Norte Centro #020VSS008': 'MX-CHH',
                'PGR-Delegación Estatal Querétaro #017000013': 'MX-QUE',
                'IFT-Dirección de Procedimientos de Adquisiciones #043D00001': 'MX-CMX',
                'SAT-Subadministración de Recursos y Servicios de Mérida #006E00029': 'MX-YUC',
                'PGR-Subdelegación Administrativa #017000004': 'MX-SIN',
                'SESNSP-Dirección General de Administración #004W00001': 'MX-CMX',
                'SAT-SERVICIO DE ADMINISTRACION TRIBUTARIA #006E00034': 'MX-SON',
                'SCT-Residencia General de Carreteras Alimentadoras Zona Oriente #009000967': 'MX-OAX',
                'INACIPE-Dirección de Administración #017SKC002': 'MX-CMX',
                'DICONSA-Gerencia de Sucursal Sureste #020VSS001': 'MX-TAB',
                'API-Salina Cruz-Gerencia de Operaciones e Ingeniería #009J3G999': 'MX-OAX',
                'DICONSA-DICONSA S.A. DE C.V. SUCURSAL SUR #020VSS017': 'MX-PUE',
                'DICONSA-Diconsa S.A. de C.V. Sucursal Centro #020VSS011': 'MX-JAL',
                'DICONSA-Sucursal Norte #020VSS999': 'MX-NLE',
                'SRE-Director General Adjunta de Adquisiciones y Cotrol de Bienes #005000998': 'MX-CMX',
                'PRS-OADPRS Dirección General de Admonistración #004D00001': 'MX-CMX',
                'PROSPERA-Oficinas Centrales #020G00001': 'MX-CMX',
                'BIENESTAR-Subdelegación de Administración #020000011': 'MX-CHH',
                'SAT-Subadministración de Recursos y Servicios de Naucalpan #006E00036': 'MX-MEX',
                'BIENESTAR-Del. SEDESOL en Yucatán, Subdelegación de Administración #020000992': 'MX-YUC',
                'DICONSA-Gerencia de la Sucursal #020VSS013': 'MX-OAX',
                'LICONSA-Subgerencia de Administración y Finanzas #020VST024': 'MX-CAM',
                'LICONSA-Subgerencia de Administración y Finanzas GEVT #020VST010': 'MX-MEX',
                'LICONSA-Dirección de Producción #020VST011': 'MX-MEX',
                'BIENESTAR-Delegación Sedesol en el Estado de Michoacán #020000018': 'MX-MIC',
                'API-Salina Cruz-Departamento de Recursos Materiales #009J3G001': 'MX-OAX',
                'PROSPERA-Delegación PROSPERA en Yucatán #020G00004': 'MX-YUC',
                'SADER-Unidad de Recursos Materiales y Servicios Generales #008000968': 'MX-JAL',
                'LICONSA-Subdirección de Adquisición y Distribución de Materiales #020VST004': 'MX-MEX',
                'SCT-Dirección General de Programación, Organización y Presupuesto #009000941': 'MX-CMX',
                'DICONSA-DICONSA Sucursal Michoacán #020VSS004': 'MX-MIC',
                'API-Coatzacoalcos-Coatzacoalcos Jefatura de Proyectos y Construcción #009J3F001': 'MX-VER',
                'VER-Institutos Tecnológicos Superiores-DEPARTAMENTO DE RECURSOS MATERIALES Y SERVICIOS #930054947': 'MX-VER',
                'DICONSA-Coordinación de Administración y Recursos Humanos #020VSS003': 'MX-YUC',
                'VER-Institutos Tecnológicos Superiores-RECURSOS MATERIALES Y SERVICIOS GENERALES #930054939': 'MX-VER',
                'SCT-Unidad de Tecnologías de Información y Comunicaciones #009000982': 'MX-CMX',
                'DICONSA-Gerencia de Sucursal Bajío #020VSS014': 'MX-QUE',
                'LICONSA-LICONSA, S.A. DE C.V. 2 #020VST020': 'MX-CHP',
                'LICONSA-Subgerencia de Administración y Finanzas en Jiquilpan Michoacán #020VST007': 'MX-MIC',
                'CRE-Oficialía Mayor #045000001': 'MX-CMX',
                'DICONSA-Diconsa, S.A de C.V. (Sucursal Pacifico) #020VSS007': 'MX-SIN',
                'DICONSA-SUCURSAL SUR #020VSS006': 'MX-PUE',
                'PROSPERA-Delegación Estatal Querétaro #020G00992': 'MX-QUE',
                'PGR-Departamento de Recursos Materiales #017000020': 'MX-CAM',
                'PGR-Subdelegación Administrativa #017000032': 'MX-NAY',
                'SCT-DIRECCION GENERAL DE PROTECCION Y MEDICINA PREVENTIVA EN EL TRANSPORTE #009000072': 'MX-CMX',
                'SAT-AGRS ACRM Administración de Recursos Materiales #006E00014': 'MX-CMX',
                'SADER-UNIDAD DE ADMON. DE REC. MAT. Y SERVS. GRALES. #008000963': 'MX-CMX',
                'VER-Institutos Tecnológicos Superiores-Departamento de Recursos Materiales y Servicios Generales #930054926': 'MX-VER',
                'DICONSA-Sucursal Estatal Metropolitana #020VSS010': 'MX-MEX',
                'LICONSA-Gerencia Metropolitana Norte #020VST002': 'MX-MEX',
                'FIT-Gerencia de Adquisiciones, Recursos Materiales y Obra Pública, #009J3L001': 'MX-CMX',
                'CNBBBJ-Oficinas Centrales #020G00001': 'MX-CMX',
                'COFECE-Dirección Ejecutiva de Recursos Materiales, Adquisiciones y Servicios #041A00001': 'MX-CMX',
                'PGR-Subdelegación Administrativa #017000988': 'MX-GUA',
                'INAI-Dirección General de Administración #006HHE001': 'MX-CMX',
                'PRS-Dirección General de Administración #004D00001': 'MX-CMX',
                'CNBBBJ-COORDINACION NACIONAL DEL PROGRAMA DE DESARROLLO HUMANO PROSPERA #020G00973': 'MX-ZAC',
                'CNPSS-Dirección General de Administración y Finanzas #012U00999': 'MX-CMX',
                'LICONSA-Subdirección de Adquisición de Leche #020VST012': 'MX-MEX',
                'API-Coatzacoalcos-Gerencia de Administración y Finanzas #009J3F002': 'MX-VER',
                'CNBBBJ-Delegación Estatal Nuevo León #020G00989': 'MX-NLE',
                'API-Salina Cruz-Subgerencia de Administración #009J3G001': 'MX-OAX',
                'PGR-Subdelegación Administrativa #017000990': 'MX-HID',
                'CNBBBJ-Programa de Inclusión Social, Del. Estatal Ciudad de México #020G00971': 'MX-CMX',
                'PGR-DELEGACION EN EL DISTRITO FEDERAL #017000017': 'MX-CMX',
                'PGR-Subdelegacion Administrativa #017000005': 'MX-CHP',
                'PGR-Subdelegación Administrativa #017000989': 'MX-TLA',
                'PROSPERA-COORDINACION NACIONAL DEL PROGRAMA DE DESARROLLO HUMANO PROSPERA #020G00973': 'MX-ZAC',
                'SCT-Dirección General de Comunicación Social #009000069': 'MX-CMX',
                'AGN-Archivo General de la Nación #004EZN999': 'MX-CMX',
                'PROSPERA-Coordinación Nacional del Programa de Desarrollo Humano Oportunidades #020G00993': 'MX-BCN',
                'SE-Secretaría Técnica #010102996': 'MX-CMX',
                'PROSPERA-Programa de Inclusión Social, Del. Estatal Ciudad de México #020G00971': 'MX-CMX',
                'PROSPERA-Subdirección de Administración #020G00011': 'MX-MIC',
                'PROSPERA-Delegación Estatal Nuevo León #020G00989': 'MX-NLE',
                'SADER-Subdelegacion Administrativa Región Lagunera #008000984': 'MX-DUR',
                'PROSPERA-Delegación de la Coordinación del Programa de Inclusión Social PROSPERA #020G00995': 'MX-MOR',
                'BIENESTAR-Subdelegación de Desarrollo Social y Humano #020000005': 'MX-SIN',
                'CNPSS-Dirección de Recursos Materiales y Servicios Generales #012U00999': 'MX-CMX',
                'SCT-00009046 #009000972': 'MX-OAX',
                'VER-Institutos Tecnológicos Superiores-Instituto Tecnológico Superior de Huatusco #930054949': 'MX-VER',
                'VER-Secretaría de Desarrollo Social-SecretarÃ\xada de Medio Ambiente #930008971': 'MX-VER',
                'PGR-Subdelegación Administrativa #017000033': 'MX-VER',
                'VER-Institutos Tecnológicos Superiores-DEPARTAMENTO DE RECURSOS MATERIALES #930054917': 'MX-VER',
                'BIENESTAR-Subdelegación de Administración #020000881': 'MX-TLA',
                'LICONSA-LICONSA,S.A. DE C.V. #020VST027': 'MX-COA',
                'SPF-Dirección de Adquisiciones #004O00001': 'MX-CMX',
                'AGN-Archivo General de la Nación #047EZN999': 'MX-AGU',
                'LICONSA-Liconsa, S.A. de C.V. 1 #020VST029': 'MX-PUE',
                'STPS-Administración #014000966': 'MX-CMX',
                'PROSPERA-Oportunidades Coordinación Nacional del Programa de Desarrollo Humana Oportunidades #020G00976': 'MX-NAY',
                'PROSPERA-Delegación Estatal de PROSPERA Programa de Inclusión Social en el Estado de México #020G00968': 'MX-MEX',
                'STPS-Departamento Administrativo #014000987': 'MX-CHH',
                'PGR-Subdelegación Administrativa #017000008': 'MX-GRO',
                'LICONSA-Área de Adquisiciones #020VST992': 'MX-SLP',
                'VER-Institutos Tecnológicos Superiores-Subdirección Administrativa #930054968': 'MX-VER'}

# %%
cnts[cnts.b_entidad_federativa.isna()]['nombre_de_la_uc'].unique()
# Out:
# array(['LICONSA-Adquisiciones y Servicios Generales #020VST002',
#        'Tribunales Agrarios-Dirección General de Recursos Materiales #031000001',
#        'LICONSA-Subdirección de Adquisición de Leche en Naucalpan, Estado de México #020VST012',
#        'SAT-Administración General de Recursos y Servicios, Administración Central de Recursos Materiales #006E00001',
#        'CISEN-Dirección de Recursos Materiales y Servicios Generales #004I00001',
#        'PF-Dir. Gral. de Rec. Mat. a través de la Dir. de Adquisiciones #004L00001',
#        'LICONSA-Subdirección de Adquisiciones de Consumo Interno #020VST001',
#        'DICONSA-Dirección de Administración y Recursos Humanos #020VSS005',
#        'SPF-DIRECCIÓN DE ADQUISICIONES #004O00001',
#        'SCT-Coordinación Administrativa de la Oficialía Mayor #009000989',
#        'SE-Dirección de Contrataciones #010000999',
#        'IFAI-Dirección General de Administración #006HHE001',
# ...

# %%
cnts.head()
# Out:
#   gobierno   siglas                                        dependencia  \
# 0      APF      CFE                   Comisión Federal de Electricidad
# 1      APF  LICONSA                              Liconsa, S.A. de C.V.
# 2      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 3      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 4      APF      CFE                   Comisión Federal de Electricidad
#
#      claveuc                                    nombre_de_la_uc  \
# 0  018TOQ045  CFE-Central Termoeléctrica Punta Prieta en La ...
# 1  020VST004  LICONSA-Subdirección de Adquisición y Distribu...
# 2  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 3  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 4  018TOQ011  CFE-DEPTO. DE COMPRAS DE LA DIVISION BAJIO #01...
#
#                      responsable codigo_expediente tipo_contratacion  \
# 0  Jose Ascención Salas Pallares            117806     Adquisiciones
# ...

# %%
cnts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249835 entries, 0 to 1249834
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   gobierno               1249835 non-null  object
#  1   siglas                 1249835 non-null  object
#  2   dependencia            1249835 non-null  object
#  3   claveuc                1249835 non-null  object
#  4   nombre_de_la_uc        1249835 non-null  object
#  5   responsable            1249835 non-null  object
#  6   codigo_expediente      1249835 non-null  object
#  7   tipo_contratacion      1247187 non-null  object
#  8   tipo_procedimiento     1249425 non-null  object
#  9   fecha_inicio           1249835 non-null  object
#  10  fecha_fin              1249761 non-null  object
#  11  importe_contrato       1249835 non-null  float64
#  12  moneda                 1249835 non-null  object
#  13  folio_rupc             583532 non-null   float64
# ...

# %%
cnts.head()
# Out:
#   gobierno   siglas                                        dependencia  \
# 0      APF      CFE                   Comisión Federal de Electricidad
# 1      APF  LICONSA                              Liconsa, S.A. de C.V.
# 2      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 3      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 4      APF      CFE                   Comisión Federal de Electricidad
#
#      claveuc                                    nombre_de_la_uc  \
# 0  018TOQ045  CFE-Central Termoeléctrica Punta Prieta en La ...
# 1  020VST004  LICONSA-Subdirección de Adquisición y Distribu...
# 2  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 3  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 4  018TOQ011  CFE-DEPTO. DE COMPRAS DE LA DIVISION BAJIO #01...
#
#                      responsable codigo_expediente tipo_contratacion  \
# 0  Jose Ascención Salas Pallares            117806     Adquisiciones
# ...

# %%
cnts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249835 entries, 0 to 1249834
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   gobierno               1249835 non-null  object
#  1   siglas                 1249835 non-null  object
#  2   dependencia            1249835 non-null  object
#  3   claveuc                1249835 non-null  object
#  4   nombre_de_la_uc        1249835 non-null  object
#  5   responsable            1249835 non-null  object
#  6   codigo_expediente      1249835 non-null  object
#  7   tipo_contratacion      1247187 non-null  object
#  8   tipo_procedimiento     1249425 non-null  object
#  9   fecha_inicio           1249835 non-null  object
#  10  fecha_fin              1249761 non-null  object
#  11  importe_contrato       1249835 non-null  float64
#  12  moneda                 1249835 non-null  object
#  13  folio_rupc             583532 non-null   float64
# ...

# %%
cnts['i_ramo'].unique()
# Out:
# array([ 18,  20,  51,   6,   4,  50,  12, 913,  38,   9, 920, 926, 931,
#        900, 902,  16,  10,  11, 910,  21, 160, 925, 130,  48,  14, 917,
#          8, 310, 914, 370,  41,  60, 170, 320, 928, 200, 932, 915, 110,
#         47, 484, 919, 700, 903, 905, 923, 901, 270, 909, 401, 800, 400,
#        815, 828,  15, 930, 500, 916, 140, 801, 921, 830, 927, 600, 827,
#        810, 805, 100, 922, 912, 904, 599, 120, 180, 821, 819, 823, 924,
#        907, 811, 818, 911,   7, 210, 831, 825, 826, 450, 822, 908, 807,
#        101, 816,  43,  17, 906, 832, 918, 803, 814, 820, 813, 150, 808,
#        802, 929,  46, 812, 804, 824, 806, 829, 809,  49,   2,  40,  44,
#         36,  31,  32,  37,  45,   5,  13,  27, 817])

# %%
cnts['i_ramo'] = cnts.claveuc.apply(lambda x: int(x[:3]))

# %%
cnts.to_csv('/home/rdora/declaranet/data/pre-process/contratos_2.csv', index=False)

# %%
cnts.head()
# Out:
#   gobierno   siglas                                        dependencia  \
# 0      APF      CFE                   Comisión Federal de Electricidad
# 1      APF  LICONSA                              Liconsa, S.A. de C.V.
# 2      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 3      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 4      APF      CFE                   Comisión Federal de Electricidad
#
#      claveuc                                    nombre_de_la_uc  \
# 0  018TOQ045  CFE-Central Termoeléctrica Punta Prieta en La ...
# 1  020VST004  LICONSA-Subdirección de Adquisición y Distribu...
# 2  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 3  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 4  018TOQ011  CFE-DEPTO. DE COMPRAS DE LA DIVISION BAJIO #01...
#
#                      responsable codigo_expediente tipo_contratacion  \
# 0  Jose Ascención Salas Pallares            117806     Adquisiciones
# ...

# %%
cnts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249835 entries, 0 to 1249834
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   gobierno               1249835 non-null  object
#  1   siglas                 1249835 non-null  object
#  2   dependencia            1249835 non-null  object
#  3   claveuc                1249835 non-null  object
#  4   nombre_de_la_uc        1249835 non-null  object
#  5   responsable            1249835 non-null  object
#  6   codigo_expediente      1249835 non-null  object
#  7   tipo_contratacion      1247187 non-null  object
#  8   tipo_procedimiento     1249425 non-null  object
#  9   fecha_inicio           1249835 non-null  object
#  10  fecha_fin              1249761 non-null  object
#  11  importe_contrato       1249835 non-null  float64
#  12  moneda                 1249835 non-null  object
#  13  folio_rupc             583532 non-null   float64
# ...

# %%
cnts.head()
# Out:
#   gobierno   siglas                                        dependencia  \
# 0      APF      CFE                   Comisión Federal de Electricidad
# 1      APF  LICONSA                              Liconsa, S.A. de C.V.
# 2      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 3      APF   ISSSTE  Instituto de Seguridad y Servicios Sociales de...
# 4      APF      CFE                   Comisión Federal de Electricidad
#
#      claveuc                                    nombre_de_la_uc  \
# 0  018TOQ045  CFE-Central Termoeléctrica Punta Prieta en La ...
# 1  020VST004  LICONSA-Subdirección de Adquisición y Distribu...
# 2  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 3  051GYN023  ISSSTE-Delegación Estatal Morelos-Subdelegació...
# 4  018TOQ011  CFE-DEPTO. DE COMPRAS DE LA DIVISION BAJIO #01...
#
#                      responsable codigo_expediente tipo_contratacion  \
# 0  Jose Ascención Salas Pallares            117806     Adquisiciones
# ...

# %%
ren = {'Ramo': 'ramo',
       'Clave de la UC': 'claveuc',
       'Entidad Federativa': 'b_entidad_federativa'}
uc = uc.rename(columns=ren)[['ramo', 'claveuc', 'b_entidad_federativa']]

# %%
uc.nunique()
# Out:
# ramo                      98
# claveuc                 5558
# b_entidad_federativa      32
# dtype: int64

# %%
uc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5558 entries, 0 to 5557
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ramo                  5558 non-null   int64
#  1   claveuc               5558 non-null   object
#  2   b_entidad_federativa  5558 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 130.4+ KB

# %%
cnts = pd.merge(cnts, uc, how='left', on='claveuc')

# %%
contratosc = contratos[contratos['folio_rupc'].notna()]
contratoss = contratos[contratos['folio_rupc'].isna()]

# %%
contratosc = pd.merge(contratosc, rupc, how='left', on='folio_rupc')

contratoss = pd.merge(contratoss, sinrupc, how='left', on='proveedor_contratista')

# %%
cnts = pd.concat([contratosc, contratoss]).dropna(subset=['s_entidad_federativa', 'person'])

# %%
cnts = cnts.drop(col_drop, axis=1)

# %%
expediente = expediente.drop_duplicates(subset=['codigo_expediente'])

# %%
cnts = pd.merge(cnts, expediente, how='left', on='codigo_expediente')

# %%
ef = cnts.loc[cnts.s_entidad_federativa.str.contains('MX-'), 's_entidad_federativa'].unique()

# %%
ef2 = ['sinaloa', 'jalisco', 'morelos', 'ciudad de mexico', 'mexico', 'veracruz',
       'chiapas', 'sonora', 'tabasco', 'nuevo leon', 'tamaulipas', 'durango',
       'baja california sur', 'baja california', 'queretaro', 'puebla', 'san luis potosi', 'oaxaca',
       'michoacan', 'yucatan', 'coahuila', 'guanajuato', 'hidalgo', 'colima',
       'chihuahua', 'zacatecas', 'aguascalientes', 'quintana roo', 'guerrero', 'campeche',
       'nayarit', 'tlaxcala']

# %%
rep = dict(zip(ef2, ef))

# %%
cnts['entidad_federativa'] = cnts.entidad_federativa.replace(rep)
